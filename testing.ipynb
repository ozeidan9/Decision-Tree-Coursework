# %% [markdown]
# # This notebook will be used for testing each section

# %%
from src.main import *
from src.treegen import *
from src.optimalsplit import *
from src.crosseval import *
from src.prune import *
import importlib

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
treeNode = tree_gen()
# Steps to visualise:
root, depth = treeNode.generate_decision_tree(treeNode.sample_data, 0)
#fig, ax = plt.subplots(figsize=(18, 10))
#gap = 1.0/depth
#treeNode.visualize_tree(root, 0.0, 1.0, 0.0, 1.0)
#fig.subplots_adjust(top=0.83)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13344/1035788102.py in <module>
#       1 treeNode = tree_gen()
#       2 # Steps to visualise:
# ----> 3 root, depth = treeNode.generate_decision_tree(treeNode.sample_data, 0)
#       4 #fig, ax = plt.subplots(figsize=(18, 10))
#       5 #gap = 1.0/depth
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      42             left_dataset = training_dataset[l]
#      43             right_dataset = training_dataset[r]
# ---> 44             left_branch, left_depth = self.generate_decision_tree(left_dataset, depth+1)
#      45             right_branch, right_depth = self.generate_decision_tree(right_dataset, depth+1)
#      46             node = tree(attribute=attribute, val=value, left=left_branch, right=right_branch)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in generate_decision_tree(self, training_dataset, depth)
#      37         # else, find the best split and return a node with the best split and depth
#      38         else:
# ---> 39             value, attribute = self.find_split(training_dataset)
#      40             l =np.where(training_dataset[:, attribute-1] <= value)
#      41             r =np.where(training_dataset[:, attribute-1] > value)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in find_split(self, training_dataset)
#      61                 #Split array into top and bottom, and add
#      62                 topEntropy = self.compute_entropy(training_dataset[0:row, column]) * training_dataset[0:row, column].size
# ---> 63                 bottomEntropy = self.compute_entropy(training_dataset[row:training_dataset.shape[0], column]) * training_dataset[row:training_dataset.shape[0], column].size
#      64                 totalEntropy = bottomEntropy + topEntropy
#      65                 #print(totalEntropy)
#
# c:\Users\Shaheen\OneDrive - Imperial College London\Uni\Lab Files\Machine Learning\Coursework\1\Decision-Tree-Coursework\src\treegen.py in compute_entropy(self, training_dataset)
#      77         entropy = 0
#      78         #Need elements as a histogram
# ---> 79         elements, count = np.unique(training_dataset, return_counts=True)
#      80         for i in range(len(elements)):
#      81             elementProb = count[i]/sum(count)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\numpy\core\overrides.py in unique(*args, **kwargs)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     331         aux = ar[perm]
#     332     else:
# --> 333         ar.sort()
#     334         aux = ar
#     335     mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:
